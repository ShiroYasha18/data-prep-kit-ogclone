# %% [markdown]
# repo_level_order Transform Sample Notebook
#
# **** These pip installs need to be adapted to use the appropriate release level. Alternatively, The venv running the jupyter lab could be pre-configured with a requirement file that includes the right release. Example for transform developers working from git clone:
# make venv
# source venv/bin/activate
# pip install jupyterlab
# venv/bin/jupyter lab

# %%
# %%capture
## This is here as a reference only
# Users and application developers must use the right tag for the latest from pypi
# %pip install 'data-prep-toolkit-transforms[repo_level_order]'
! pip install pandas

# %% [markdown]
# ***** Import required classes and modules

# %%
from dpk_repo_level_order.ray.runtime import RepoLevelOrderRay

# %%
RepoLevelOrderRay(input_folder= "test-data/input",
            output_folder= "output",
            ).transform()
# Out:
# 23:30:51 INFO - pipeline id pipeline_id
# 23:30:51 INFO - code location None
# 23:30:51 INFO - number of workers 1 worker options {'num_cpus': 0.8, 'max_restarts': -1}
# 23:30:51 INFO - actor creation delay 0
# 23:30:51 INFO - job details {'job category': 'preprocessing', 'job name': 'repo_lvl', 'job type': 'ray', 'job id': 'job_id'}
# 23:30:51 INFO - data factory data_ is using local data access: input_folder - test-data/input output_folder - output
# 23:30:51 INFO - data factory data_ max_files -1, n_sample -1
# 23:30:51 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 23:30:51 INFO - connecting to existing cluster
# 23:30:51 INFO - Connecting to the existing Ray cluster
# Creating Store Params
# 2025-04-24 23:30:52,087	INFO client_builder.py:244 -- Passing the following kwargs to ray.init() on the server: ignore_reinit_error
# ...
